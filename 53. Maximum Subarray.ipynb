# %%
#Time Limit Exceeded
nums = [-2,1,-3,4,-1,2,1,-5,4] # 6 [4,-1,2,1]
#nums = [1] # 1 [1]
#nums = [5,4,-1,7,8] # 23 [5,4,-1,7,8]
left=0
right=0
ans=nums[0]
while left < len(nums):
  totle=sum(nums[left:right+1])
  if ans < totle:
    ans=totle
    i=left
    j=right+1
  right += 1
  if right == len(nums):
    left += 1
    right=left
print(ans)
print(nums[i:j])
# Out:
# 23
# [5, 4, -1, 7, 8]

# %%
#Solution  #https://www.youtube.com/watch?v=SsJe0gPmlL8 6:12
nums = [-2,1,-3,4,-1,2,1,-5,4] # 6 [4,-1,2,1]
#nums = [1] # 1 [1]
#nums = [5,4,-1,7,8] # 23 [5,4,-1,7,8]
max_sum=float('-inf')
start=0
end=0
current_sum=0

for i in range(len(nums)):
  current_sum += nums[i]

  if current_sum > max_sum:
    max_sum=current_sum
    end=i+1
  
  if current_sum < 0:
    current_sum=0
    start=end+1
max_sum
# Out:
# 6
