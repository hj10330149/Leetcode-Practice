# %%
nums = [-1,0,1,2,-1,-4]
nums = [0,1,1]
nums = [0,0,0]
nums = [0,0,0,0]
nums = [-2,0,1,1,2]
nums = [-1,0,1,2,-1,-4,-2,-3,3,0,4]
new_nums=sorted(nums)
left=0
right=1
end=len(nums)-1
ans=[]
while left < (len(nums)-2):
  if new_nums[left]+new_nums[right] > 0:
    break
  if abs(new_nums[left]+new_nums[right]) > new_nums[end]:
    left += 1
    right = left +1
    end=len(nums)-1
  elif abs(new_nums[left]+new_nums[right]) < new_nums[end]:
    end -=1
    if end == right:
        left += 1
        right = left +1
        end=len(nums)-1
  else:
    list=[new_nums[left], new_nums[right], new_nums[end]]
    if list not in ans:
      ans.append(list)
    right += 1
    end=len(nums)-1
    if end == right:
      left += 1
      right = left +1
      end=len(nums)-1
ans
# Out:
# [[-2, -1, 3], [-2, 0, 2], [-1, -1, 2], [-1, 0, 1]]

# %%
nums = [6,-5,-6,-1,-2,8,-1,5,-10,-8,-10,-2,-4,-1,-8,-2,8,9,-5,-2,-8,-9,-3,-5]
new_nums=sorted(nums)
new_nums
# Out:
# [-10,
#  -10,
#  -9,
#  -8,
#  -8,
#  -8,
#  -6,
#  -5,
#  -5,
#  -5,
#  -4,
#  -3,
#  -2,
#  -2,
#  -2,
#  -2,
#  -1,
#  -1,
#  -1,
#  5,
#  6,
#  8,
#  8,
#  9]

# %%
nums = [6,-5,-6,-1,-2,8,-1,5,-10,-8,-10,-2,-4,-1,-8,-2,8,9,-5,-2,-8,-9,-3,-5]

new_nums=sorted(nums)
left=0
right=1
end=len(nums)-1
ans=[]
while left < (len(nums)-2):
  if (new_nums[left] >= 0) & (new_nums[left]+new_nums[right] > 0):
    break
  if abs(new_nums[left]+new_nums[right]) > new_nums[end]:
    right += 1
  elif abs(new_nums[left]+new_nums[right]) < new_nums[end]:
    end -= 1  
  else:
    list=[new_nums[left], new_nums[right], new_nums[end]]
    if list not in ans:
      ans.append(list)
    right += 1
    end=len(nums)-1
  while new_nums[right] == new_nums[right-1]:
    right += 1
    if end == right:
      left += 1
      right = left +1
      end=len(nums)-1
  if end == right:
    left += 1
    right = left +1
    end=len(nums)-1
ans
# Out:
# [[-8, -1, 9],
#  [-6, -3, 9],
#  [-6, -2, 8],
#  [-5, -4, 9],
#  [-5, -3, 8],
#  [-5, -1, 6],
#  [-4, -2, 6],
#  [-4, -1, 5],
#  [-3, -2, 5]]

# %%
nums=[-8,-8,-8,-8,-8,-1,-1,-1,9,9,9]
right=0
nums[right-1]
# Out:
# 9
