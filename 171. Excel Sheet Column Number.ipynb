# %%
columnTitle = "A"
import string
A_to_Z=dict(zip(string.ascii_uppercase, range(1,27)))
columnTitle=str(columnTitle[::-1])
ans=0
for i in range(len(columnTitle)):
    ans += A_to_Z[columnTitle[i]]*(26**i)
print(ans)
# Out:
# 1
