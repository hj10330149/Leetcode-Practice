# %%
digits = [1,2,3]
i=1
while digits[-i] == 9:
    digits[-i]=0
    i +=1
    if i>len(digits):
        digits.insert(0,1)
        break
else:
    digits[-i]=digits[-i]+1
print(digits)
# Out:
# [1, 2, 4]
