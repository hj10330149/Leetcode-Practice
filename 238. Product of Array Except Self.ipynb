# %%
#Time Limit Exceeded
nums = [-1,1,0,-3,3]
ans=[]
for j in range(len(nums)):
  a=list(nums)
  a.pop(j)
  prod = 1
  for i in a:
    prod *= i
  ans.append(prod)
ans
# Out:
# [0, 0, 9, 0, 0]

# %%
#Solution 看不懂解答ㄏㄏ
def productExceptSelf(self, nums: List[int]) -> List[int]:
   res = []
        
   acc = 1
   for n in nums:
     res.append(acc)
     cc *= n

   acc = 1 
   for i in reversed(range(len(nums))): #這啥拉
     res[i] *= acc
     acc *= nums[i]
            
   return(res)
